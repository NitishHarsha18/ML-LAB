# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishHarsha18/ML-LAB/blob/main/ML_assign_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import csv

# %%
csvdf=pd.read_csv('/content/ML-ASSIGNMENT_2.csv')

# %%
csvdf
# Out:
#     S.NO HALLTICKET NO                    NAME  ...     ASSIGNMENT      MARKS RESULT
# 0      1    19h61a3501              A.RAJKUMAR  ...       very bad       good   PASS
# 1      2    19h61a3502       A.SAI RAHUL REDDY  ...      excellent  excellent   PASS
# 2      3    19h61a3503      A.DEEPTHI CHOWDARY  ...      excellent  excellent   PASS
# 3      4    19h61a3504          A.HEMANT KUMAR  ...      excellent  excellent   PASS
# 4      5    19h61a3505          A.SOWMYA REDDY  ...      excellent  excellent   PASS
# ..   ...           ...                     ...  ...            ...        ...    ...
# 59    60    20H65A3502     VENKATESHWARA REDDY  ...      excellent  excellent   PASS
# 60    61    20H65A3503               S.TEJASWI  ...      excellent  excellent   PASS
# 61    62    20H65A3504                MA.RAHIL  ...  below average     absent   FAIL
# 62    63    20H65A3505  G.SAI SIDDHAERTH REDDY  ...           good  excellent   PASS
# ...

# %%
positive = csvdf[csvdf['RESULT']=='PASS']
positive
# Out:
#     S.NO HALLTICKET NO  ...      MARKS RESULT
# 0      1    19h61a3501  ...       good   PASS
# 1      2    19h61a3502  ...  excellent   PASS
# 2      3    19h61a3503  ...  excellent   PASS
# 3      4    19h61a3504  ...  excellent   PASS
# 4      5    19h61a3505  ...  excellent   PASS
# 5      6    19h61a3506  ...  excellent   PASS
# 6      7    19h61a3507  ...  excellent   PASS
# 7      8    19h61a3508  ...  excellent   PASS
# 8      9    19h61a3509  ...  excellent   PASS
# 9     10    19h61a3510  ...  excellent   PASS
# 10    11    19h61a3511  ...  excellent   PASS
# 12    13    19h61a3513  ...  excellent   PASS
# 13    14    19h61a3514  ...  excellent   PASS
# 14    15    19h61a3515  ...  excellent   PASS
# 15    16    19h61a3516  ...       good   PASS
# 16    17    19h61a3517  ...  excellent   PASS
# 17    18    19h61a3518  ...  excellent   PASS
# 18    19    19h61a3519  ...  excellent   PASS
# 19    20    19h61a3520  ...  excellent   PASS
# ...

# %%
negative = csvdf[csvdf['RESULT']=='FAIL']
negative
# Out:
#     S.NO HALLTICKET NO              NAME GENDER      ASSIGNMENT    MARKS RESULT
# 11    12    19h61a3512  C.MANIDEEP REDDY       M  below average  average   FAIL
# 39    40    19h61a3541          P.SAKETH       M      excellent   absent   FAIL
# 43    44    19h61a3545     R.BADRI KUMAR       M           good   absent   FAIL
# 61    62    20H65A3504          MA.RAHIL       M  below average   absent   FAIL
# 63    64    20H65A3506       A.JAGADEESH       M  below average  average   FAIL
